# %% [markdown]
# **USARÉ ESTE NOTEBOOK PARA LIMPIAR EL CSV**

# %% [markdown]
# **IMPORTAMOS LAS LIBRERÍAS**

# %%
import pandas as pd

# %% [markdown]
# **IMPORTAMOS EL CSV**

# %%
df = pd.read_csv('../Data/elonmusk/2021.csv')

# %% [markdown]
# **QUE TENEMOS AQUÍ**

# %%
df.sample(3)
# Out:
#       Unnamed: 0                   id      conversation_id    created_at  \
# 4477        4477  1183580078518743041  1053390822991790083  1.571022e+12
# 8865        8865   985343867108012032   985244322772733952  1.523759e+12
# 8434        8434  1002945018066157568  1002871601405153280  1.527956e+12
#
#                      date  timezone  place  \
# 4477  2019-10-14 03:07:35         0    NaN
# 8865  2018-04-15 02:27:39         0    NaN
# 8434  2018-06-02 16:08:20         0    NaN
#
#                                                   tweet language hashtags  \
# 4477             @Charalanahzard Those rumors are false       en       []
# 8865  @TheOnion Don’t want to brag or anything, but ...       en       []
# 8434                 @SpiritosoV @KumJm @STcom Exactly!       en       []
#
#       ... geo  source  user_rt_id user_rt retweet_id  \
# 4477  ... NaN     NaN         NaN     NaN        NaN
# 8865  ... NaN     NaN         NaN     NaN        NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12339 entries, 0 to 12338
# Data columns (total 40 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Unnamed: 0       12339 non-null  int64
#  1   id               12339 non-null  int64
#  2   conversation_id  12339 non-null  int64
#  3   created_at       12339 non-null  float64
#  4   date             12339 non-null  object
#  5   timezone         12339 non-null  int64
#  6   place            0 non-null      float64
#  7   tweet            12339 non-null  object
#  8   language         12339 non-null  object
#  9   hashtags         12339 non-null  object
#  10  cashtags         12339 non-null  object
#  11  user_id          12339 non-null  int64
#  12  user_id_str      12339 non-null  int64
#  13  username         12339 non-null  object
#  14  name             12339 non-null  object
#  15  day              12339 non-null  int64
#  16  hour             12339 non-null  int64
# ...

# %%
df['year'] = pd.DatetimeIndex(df['date']).year

# %%
df.sample()
# Out:
#        Unnamed: 0                  id     conversation_id    created_at  \
# 10111       10111  840410357122314240  839762369332985856  1.489204e+12
#
#                       date  timezone  place  \
# 10111  2017-03-11 03:53:37         0    NaN
#
#                                                    tweet language hashtags  \
# 10111  @mcannonbrookes Just spoke with @JayWeatherill...       en       []
#
#        ... source  user_rt_id  user_rt retweet_id  \
# 10111  ...    NaN         NaN      NaN        NaN
#
#                                                 reply_to  retweet_date  \
# 10111  [{'screen_name': 'mcannonbrookes', 'name': 'Mi...           NaN
#
#        translate trans_src trans_dest  year
# 10111        NaN       NaN        NaN  2017
#
# [1 rows x 40 columns]

# %%
elon = df[['id','tweet','date','nlikes','nreplies','nretweets','year']]
elon.head()
# Out:
#                     id                                              tweet  \
# 0  1373819373090050048  @bluemoondance74 @NASASpaceflight Going well. ...
# 1  1373735946244431873  @NASASpaceflight Hopefully will happen this de...
# 2  1373555480870621188                                 @newscientist True
# 3  1373507545315172357  @cleantechnica I am accumulating resources to ...
# 4  1373492611231535111  @CathieDWood When vast amounts of manufacturin...
#
#                   date  nlikes  nreplies  nretweets  year
# 0  2021-03-22 02:10:37    2678       234        134  2021
# 1  2021-03-21 20:39:07    7967       535        570  2021
# 2  2021-03-21 08:42:00   15510       539        409  2021
# 3  2021-03-21 05:31:31  143476     10500      12483  2021
# 4  2021-03-21 04:32:11    6568       376        425  2021

# %%
elon['name'] = 'Elon'
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/3857757371.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon['name'] = 'Elon'

# %%
elon['surname'] = 'Musk'
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/3284001158.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon['surname'] = 'Musk'

# %%
elon["nlikes"] = df["nlikes"].astype(dtype="int64")
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/4197203895.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon["nlikes"] = df["nlikes"].astype(dtype="int64")

# %%
elon["nreplies"] = df["nreplies"].astype(dtype="int64")
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/1881173030.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon["nreplies"] = df["nreplies"].astype(dtype="int64")

# %%
elon["nretweets"] = df["nretweets"].astype(dtype="int64")
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/1712450999.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon["nretweets"] = df["nretweets"].astype(dtype="int64")

# %%
elon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12339 entries, 0 to 12338
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         12339 non-null  int64
#  1   tweet      12339 non-null  object
#  2   date       12339 non-null  object
#  3   nlikes     12339 non-null  int64
#  4   nreplies   12339 non-null  int64
#  5   nretweets  12339 non-null  int64
#  6   year       12339 non-null  int64
#  7   name       12339 non-null  object
#  8   surname    12339 non-null  object
# dtypes: int64(5), object(4)
# memory usage: 867.7+ KB

# %%
elon.isnull().sum()
# Out:
# id           0
# tweet        0
# date         0
# nlikes       0
# nreplies     0
# nretweets    0
# year         0
# name         0
# surname      0
# dtype: int64

# %%
elon.tail()
# Out:
#                        id                                              tweet  \
# 12334  142881284019060736                  That was a total non sequitur btw
# 12335  142880871391838208  Great Voltaire quote, arguably better than Twa...
# 12336  142188458125963264  I made the volume on the Model S  http://t.co/...
# 12337  142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 12338         15434727182  Please ignore prior tweets, as that was someon...
#
#                       date  nlikes  nreplies  nretweets  year  name surname
# 12334  2011-12-03 08:22:07      53        31          6  2011  Elon    Musk
# 12335  2011-12-03 08:20:28      29         7         25  2011  Elon    Musk
# 12336  2011-12-01 10:29:04      78        31          9  2011  Elon    Musk
# 12337  2011-12-01 09:55:11     189        32         15  2011  Elon    Musk
# 12338  2010-06-04 18:31:57    4652       391        348  2010  Elon    Musk

# %%
elon['tweet'] = elon['tweet'].astype(str)
# Out:
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_78109/969354319.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   elon['tweet'] = elon['tweet'].astype(str)

# %%
print(list(elon['year'].unique()))
# Out:
# [2021, 2020, 2019, 2018, 2017, 2016, 2015, 2014, 2013, 2012, 2011, 2010]

# %%
print(list(elon['name'].unique()))
# Out:
# ['Elon']

# %%
print(list(elon['surname'].unique()))
# Out:
# ['Musk']

# %%
elon.drop([70, 80])
# Out:
#                         id                                              tweet  \
# 0      1373819373090050048  @bluemoondance74 @NASASpaceflight Going well. ...
# 1      1373735946244431873  @NASASpaceflight Hopefully will happen this de...
# 2      1373555480870621188                                 @newscientist True
# 3      1373507545315172357  @cleantechnica I am accumulating resources to ...
# 4      1373492611231535111  @CathieDWood When vast amounts of manufacturin...
# ...                    ...                                                ...
# 12334   142881284019060736                  That was a total non sequitur btw
# 12335   142880871391838208  Great Voltaire quote, arguably better than Twa...
# 12336   142188458125963264  I made the volume on the Model S  http://t.co/...
# 12337   142179928203460608  Went to Iceland on Sat to ride bumper cars on ...
# 12338          15434727182  Please ignore prior tweets, as that was someon...
#
# ...

# %% [markdown]
# **EXPORTAMOS EL CSV DEFINITIVO**

# %%
elon.to_csv('../Data/elonmusk/final4.csv')

# %%
elon.head(80)
# Out:
#                      id                                              tweet  \
# 0   1373819373090050048  @bluemoondance74 @NASASpaceflight Going well. ...
# 1   1373735946244431873  @NASASpaceflight Hopefully will happen this de...
# 2   1373555480870621188                                 @newscientist True
# 3   1373507545315172357  @cleantechnica I am accumulating resources to ...
# 4   1373492611231535111  @CathieDWood When vast amounts of manufacturin...
# ..                  ...                                                ...
# 75  1369969983632064513  @_Shameless_Plug @Falcon9Block5 @bluemoondance...
# 76  1369969332114096133  @WholeMarsBlog Like @CyberpunkGame, but *with*...
# 77  1369933283174318082  @PPathole @arstechnica @SciGuySpace If 2021 ma...
# 78  1369919659898789891           @TezlaMick @arstechnica @SciGuySpace Yes
# 79  1369918893771395078  @arstechnica @SciGuySpace Falcon 9 is almost a...
#
# ...

# %% [markdown]
# **USARÉ ESTE NOTEBOOK PARA IMPORTAR LA DATA A SQL**

# %% [markdown]
# **IMPORTAMOS LAS LIBRERÍAS**

# %%
# %pip install sqlalchemy
# %pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages (1.4.27)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages (from sqlalchemy) (1.1.2)
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: pymysql in /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages (1.0.2)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sqlalchemy as alch
import pandas as pd
from getpass import getpass
import requests
import pymysql
import dotenv
import os

# %% [markdown]
# **ALMACENAMOS LA CONTRASEÑA Y CREAMOS LA RUTA DE CONEXIÓN**

# %%
password = getpass("Introduce tu contraseña ")
db_name = "elonmusk"
conec = f"mysql+pymysql://root:{password}@localhost/{db_name}"
engine = alch.create_engine(conec)
print("Hurray")
# Out:
# Introduce tu contraseña ········
# Hurray

# %%
df = pd.read_csv('../Data/elonmusk/final2.csv')

# %% [markdown]
# **QUE TAN GRANDE ES MI DF**

# %%
df.shape
# Out:
# (12339, 10)

# %% [markdown]
# **MUY GRANDE ME TEMO, VAMOS A INTENTAR QUEDARNOS CON TODO**

# %%
df.head(3)
# Out:
#    Unnamed: 0                   id  \
# 0           0  1373819373090050048
# 1           1  1373735946244431873
# 2           2  1373555480870621188
#
#                                                tweet                 date  \
# 0  @bluemoondance74 @NASASpaceflight Going well. ...  2021-03-22 02:10:37
# 1  @NASASpaceflight Hopefully will happen this de...  2021-03-21 20:39:07
# 2                                 @newscientist True  2021-03-21 08:42:00
#
#    nlikes  nreplies  nretweets  year  name surname                nueva
# 0    2678       234        134  2021  Elon    Musk  2021-03-22 02:10:37
# 1    7967       535        570  2021  Elon    Musk  2021-03-21 20:39:07
# 2   15510       539        409  2021  Elon    Musk  2021-03-21 08:42:00

# %%
df["nueva"] = pd.to_datetime(df.date).dt.strftime('%Y-%m-%d %H:%M:%S')

# %%
df.head()
# Out:
#    Unnamed: 0                   id  \
# 0           0  1373819373090050048
# 1           1  1373735946244431873
# 2           2  1373555480870621188
# 3           3  1373507545315172357
# 4           4  1373492611231535111
#
#                                                tweet                 date  \
# 0  @bluemoondance74 @NASASpaceflight Going well. ...  2021-03-22 02:10:37
# 1  @NASASpaceflight Hopefully will happen this de...  2021-03-21 20:39:07
# 2                                 @newscientist True  2021-03-21 08:42:00
# 3  @cleantechnica I am accumulating resources to ...  2021-03-21 05:31:31
# 4  @CathieDWood When vast amounts of manufacturin...  2021-03-21 04:32:11
#
#    nlikes  nreplies  nretweets  year  name surname                nueva
# 0    2678       234        134  2021  Elon    Musk  2021-03-22 02:10:37
# 1    7967       535        570  2021  Elon    Musk  2021-03-21 20:39:07
# 2   15510       539        409  2021  Elon    Musk  2021-03-21 08:42:00
# 3  143476     10500      12483  2021  Elon    Musk  2021-03-21 05:31:31
# 4    6568       376        425  2021  Elon    Musk  2021-03-21 04:32:11

# %% [markdown]
# **CORREMOS UNA QUERY PARA COMPROBAR QUE ESTÁ TODO OKEY**
#
#      **AL NO CHEQUEAR EL ID, ME AÑADE VALORES DUPLICADOS EN SQL**

# %%
pd.read_sql_query("""SELECT * FROM user;""", engine)
# Out:
#    user_id  name surname
# 0        1  Elon    Musk

# %%
pd.read_sql_query("""SELECT * FROM tweet;""", engine)
# Out:
#     tweet_id                                              tweet  \
# 0          1  @bluemoondance74 @NASASpaceflight Going well. ...
# 1          2  @NASASpaceflight Hopefully will happen this de...
# 2          3                                 @newscientist True
# 3          4  @cleantechnica I am accumulating resources to ...
# 4          5  @CathieDWood When vast amounts of manufacturin...
# 5          6  @Swaggerheim @SciGuySpace Not trying to roast,...
# 6          7  @bluemoondance74 @NASASpaceflight Going well. ...
# 7          8  @NASASpaceflight Hopefully will happen this de...
# 8          9                                 @newscientist True
# 9         10  @cleantechnica I am accumulating resources to ...
# 10        11  @CathieDWood When vast amounts of manufacturin...
# 11        12  @Swaggerheim @SciGuySpace Not trying to roast,...
# 12        13  @bluemoondance74 @NASASpaceflight Going well. ...
# 13        14  @NASASpaceflight Hopefully will happen this de...
# 14        15                                 @newscientist True
# 15        16  @cleantechnica I am accumulating resources to ...
# 16        17  @CathieDWood When vast amounts of manufacturin...
# 17        18  @Swaggerheim @SciGuySpace Not trying to roast,...
#
#                   date  nlikes  nreplies  nretweets  user_user_id
# 0  2021-03-22 02:10:37    2678       234        134             1
# 1  2021-03-21 20:39:07    7967       535        570             1
# 2  2021-03-21 08:42:00   15510       539        409             1
# 3  2021-03-21 05:31:31  143476     10500      12483             1
# 4  2021-03-21 04:32:11    6568       376        425             1
# 5  2021-03-21 04:25:23    1773       113         67             1
# 6  2021-03-22 02:10:37    2678       234        134             1
# 7  2021-03-21 20:39:07    7967       535        570             1
# 8  2021-03-21 08:42:00   15510       539        409             1
# 9  2021-03-21 05:31:31  143476     10500      12483             1
# 10 2021-03-21 04:32:11    6568       376        425             1
# 11 2021-03-21 04:25:23    1773       113         67             1
# 12 2021-03-22 02:10:37    2678       234        134             1
# 13 2021-03-21 20:39:07    7967       535        570             1
# 14 2021-03-21 08:42:00   15510       539        409             1
# 15 2021-03-21 05:31:31  143476     10500      12483             1
# 16 2021-03-21 04:32:11    6568       376        425             1
# 17 2021-03-21 04:25:23    1773       113         67             1

# %% [markdown]
# **ESCRIBIMOS UNA FUNCIÓN QUE ITERE POR NUESTRO DATAFRAME E INSERTE LOS DATOS EN SQL "TWEET"**

# %% [markdown]
# **FUNCIÓN PARA LOS STRINGS**

# %%
def checkstr(a,string):
    """
    Función que revisa en cada tabla si el name, surname y tweet existe o no.
    Devuelve True o False en función a lo anterior
    """
    if a == "tweet":
        query = list(engine.execute(f"SELECT tweet FROM tweet WHERE tweet = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False
    
    elif a == "name":
        query = list(engine.execute(f"SELECT name FROM user WHERE name = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False
    
    elif a == "surname":
        query = list(engine.execute(f"SELECT surname FROM user WHERE surname = '{string}'"))
        if len(query) > 0:
            return True
        else:
            return False

# %% [markdown]
# **FUNCIÓN PARA LOS INT**

# %%
def checkint(a, numero):
    """
    Función que revisa en cada tabla si el id, date, nlikes, nreplies y nretweets existe o no.
    Devuelve True o False en función a lo anterior
    """
    if a == "id":
        query = list(engine.execute(f"SELECT id FROM tweet WHERE id = {numero}"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif a == "date":
        query = list(engine.execute(f"SELECT date FROM tweet WHERE date = {numero}"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif a == "nlikes":
        query = list(engine.execute(f"SELECT nlikes FROM tweet WHERE nlikes = {numero}"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif a == "nreplies":
        query = list(engine.execute(f"SELECT nreplies FROM tweet WHERE nreplies = {number}"))
        if len(query) > 0:
            return True
        else:
            return False
        
    elif a == "nretweets":
        query = list(engine.execute(f"SELECT nretweets FROM tweet WHERE nretweets = {number}"))
        if len(query) > 0:
            return True
        else:
            return False

# %% [markdown]
# **FUNCIÓN PARA LOS INT**

# %%
def insertname(name):
    """
    
    """
    for i in name:
        if checkstr("name", i):
            return "this name already exists"
        else:
            engine.execute(f"INSERT INTO user VALUES ('{i}');")

# %%
def insertsurname(surname):
    """
    
    """
    for i in surname:
        if checkstr("surname", i):
            return "this surname already exists"
        else:
            engine.execute(f"INSERT INTO user VALUES ('{i}');")

# %%
def insert(df):
    """
    Esta función inserta valores dentro de las tablas de SQL directamente desde el dataframe iterando por cada row
    """
    for i,row in df.iterrows():
        engine.execute(f"""
        INSERT INTO tweet (tweet, date, nlikes, nreplies, nretweets, user_user_id)
        VALUES ('{row.tweet}','{row.nueva}',{row.nlikes},{row.nreplies},{row.nretweets},1);""")

# %%
insert(df)
# Out:
# ---------------------------------------------------------------------------
# DataError                                 Traceback (most recent call last)
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     718     def do_execute(self, cursor, statement, parameters, context=None):
# --> 719         cursor.execute(statement, parameters)
#     720
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\xA3\\xF0\\x9F...' for column 'tweet' at row 1")
#
# The above exception was the direct cause of the following exception:
#
# DataError                                 Traceback (most recent call last)
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_85714/1110713193.py in <module>
# ----> 1 insert(df)
#
# /var/folders/lp/_3blnsw12kj309tphctgyqlr0000gn/T/ipykernel_85714/2507223289.py in insert(df)
#       4     """
#       5     for i,row in df.iterrows():
# ----> 6         engine.execute(f"""
#       7         INSERT INTO tweet (tweet, date, nlikes, nreplies, nretweets, user_user_id)
#       8         VALUES ('{row.tweet}','{row.nueva}',{row.nlikes},{row.nreplies},{row.nretweets},1);""")
#
# <string> in execute(self, statement, *multiparams, **params)
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/util/deprecations.py in warned(fn, *args, **kwargs)
#     399         if not skip_warning:
#     400             _warn_with_version(message, version, wtype, stacklevel=3)
# --> 401         return fn(*args, **kwargs)
#     402
#     403     doc = func.__doc__ is not None and func.__doc__ or ""
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    3137         """
#    3138         connection = self.connect(close_with_result=True)
# -> 3139         return connection.execute(statement, *multiparams, **params)
#    3140
#    3141     @util.deprecated_20(
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in execute(self, statement, *multiparams, **params)
#    1272             )
#    1273
# -> 1274             return self._exec_driver_sql(
#    1275                 statement,
#    1276                 multiparams,
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _exec_driver_sql(self, statement, multiparams, params, execution_options, future)
#    1576
#    1577         dialect = self.dialect
# -> 1578         ret = self._execute_context(
#    1579             dialect,
#    1580             dialect.execution_ctx_cls._init_statement,
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1843
#    1844         except BaseException as e:
# -> 1845             self._handle_dbapi_exception(
#    1846                 e, statement, parameters, cursor, context
#    1847             )
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    2024                 util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2025             elif should_wrap:
# -> 2026                 util.raise_(
#    2027                     sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2028                 )
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     205
#     206         try:
# --> 207             raise exception
#     208         finally:
#     209             # credit to
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1800                             break
#    1801                 if not evt_handled:
# -> 1802                     self.dialect.do_execute(
#    1803                         cursor, statement, parameters, context
#    1804                     )
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/sqlalchemy/engine/default.py in do_execute(self, cursor, statement, parameters, context)
#     717
#     718     def do_execute(self, cursor, statement, parameters, context=None):
# --> 719         cursor.execute(statement, parameters)
#     720
#     721     def do_execute_no_params(self, cursor, statement, context=None):
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/cursors.py in execute(self, query, args)
#     146         query = self.mogrify(query, args)
#     147
# --> 148         result = self._query(query)
#     149         self._executed = query
#     150         return result
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/cursors.py in _query(self, q)
#     308         self._last_executed = q
#     309         self._clear_result()
# --> 310         conn.query(q)
#     311         self._do_get_result()
#     312         return self.rowcount
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     546             sql = sql.encode(self.encoding, "surrogateescape")
#     547         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 548         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     549         return self._affected_rows
#     550
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     773         else:
#     774             result = MySQLResult(self)
# --> 775             result.read()
#     776         self._result = result
#     777         if result.server_status is not None:
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in read(self)
#    1154     def read(self):
#    1155         try:
# -> 1156             first_packet = self.connection._read_packet()
#    1157
#    1158             if first_packet.is_ok_packet():
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     723             if self._result is not None and self._result.unbuffered_active is True:
#     724                 self._result.unbuffered_active = False
# --> 725             packet.raise_for_error()
#     726         return packet
#     727
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/protocol.py in raise_for_error(self)
#     219         if DEBUG:
#     220             print("errno =", errno)
# --> 221         err.raise_mysql_exception(self._data)
#     222
#     223     def dump(self):
#
# /usr/local/Caskroom/miniconda/base/envs/ironhack/lib/python3.8/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     141     if errorclass is None:
#     142         errorclass = InternalError if errno < 1000 else OperationalError
# --> 143     raise errorclass(errno, errval)
#
# DataError: (pymysql.err.DataError) (1366, "Incorrect string value: '\\xF0\\x9F\\xA4\\xA3\\xF0\\x9F...' for column 'tweet' at row 1")
# [SQL:
#         INSERT INTO tweet (tweet, date, nlikes, nreplies, nretweets, user_user_id)
#         VALUES ('@johnkrausphotos 🤣🤣','2021-03-21 04:23:40',1512,70,52,1);]
# (Background on this error at: https://sqlalche.me/e/14/9h9h)

# %%
pd.read_sql_query("""SELECT * FROM tweet;""", engine)
# Out:
#     tweet_id                                              tweet  \
# 0          1  @bluemoondance74 @NASASpaceflight Going well. ...
# 1          2  @NASASpaceflight Hopefully will happen this de...
# 2          3                                 @newscientist True
# 3          4  @cleantechnica I am accumulating resources to ...
# 4          5  @CathieDWood When vast amounts of manufacturin...
# 5          6  @Swaggerheim @SciGuySpace Not trying to roast,...
# 6          7  @bluemoondance74 @NASASpaceflight Going well. ...
# 7          8  @NASASpaceflight Hopefully will happen this de...
# 8          9                                 @newscientist True
# 9         10  @cleantechnica I am accumulating resources to ...
# 10        11  @CathieDWood When vast amounts of manufacturin...
# 11        12  @Swaggerheim @SciGuySpace Not trying to roast,...
# 12        13  @bluemoondance74 @NASASpaceflight Going well. ...
# 13        14  @NASASpaceflight Hopefully will happen this de...
# 14        15                                 @newscientist True
# 15        16  @cleantechnica I am accumulating resources to ...
# 16        17  @CathieDWood When vast amounts of manufacturin...
# 17        18  @Swaggerheim @SciGuySpace Not trying to roast,...
# 18        19  @bluemoondance74 @NASASpaceflight Going well. ...
# 19        20  @NASASpaceflight Hopefully will happen this de...
# 20        21                                 @newscientist True
# 21        22  @cleantechnica I am accumulating resources to ...
# 22        23  @CathieDWood When vast amounts of manufacturin...
# 23        24  @Swaggerheim @SciGuySpace Not trying to roast,...
#
#                   date  nlikes  nreplies  nretweets  user_user_id
# 0  2021-03-22 02:10:37    2678       234        134             1
# 1  2021-03-21 20:39:07    7967       535        570             1
# 2  2021-03-21 08:42:00   15510       539        409             1
# 3  2021-03-21 05:31:31  143476     10500      12483             1
# 4  2021-03-21 04:32:11    6568       376        425             1
# 5  2021-03-21 04:25:23    1773       113         67             1
# 6  2021-03-22 02:10:37    2678       234        134             1
# 7  2021-03-21 20:39:07    7967       535        570             1
# 8  2021-03-21 08:42:00   15510       539        409             1
# 9  2021-03-21 05:31:31  143476     10500      12483             1
# 10 2021-03-21 04:32:11    6568       376        425             1
# 11 2021-03-21 04:25:23    1773       113         67             1
# 12 2021-03-22 02:10:37    2678       234        134             1
# 13 2021-03-21 20:39:07    7967       535        570             1
# 14 2021-03-21 08:42:00   15510       539        409             1
# 15 2021-03-21 05:31:31  143476     10500      12483             1
# 16 2021-03-21 04:32:11    6568       376        425             1
# 17 2021-03-21 04:25:23    1773       113         67             1
# 18 2021-03-22 02:10:37    2678       234        134             1
# 19 2021-03-21 20:39:07    7967       535        570             1
# 20 2021-03-21 08:42:00   15510       539        409             1
# 21 2021-03-21 05:31:31  143476     10500      12483             1
# 22 2021-03-21 04:32:11    6568       376        425             1
# 23 2021-03-21 04:25:23    1773       113         67             1

# %% [markdown]
# **ESCRIBIMOS UNA FUNCIÓN QUE ITERE POR NUESTRO DATAFRAME E INSERTE LOS DATOS EN SQL "USER"**

# %%
def insert(df):
    """
    Esta función inserta valores dentro de las tablas de SQL directamente desde el dataframe iterando por cada row
    """
    for i,row in df.iterrows():
        engine.execute(f"""
        INSERT INTO user 
        VALUES ('{row.id}','{row.name}','{row.surname}');""")
